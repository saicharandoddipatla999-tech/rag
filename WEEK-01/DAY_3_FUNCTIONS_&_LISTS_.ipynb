# %% [markdown]
# **Create a Multiplication Table Generator using Functions**

# %%
# Function to generate multiplication table
def multiplication_table(num):
    print(f"\nMultiplication Table of {num}\n")

    for i in range(1, 11):
        print(f"{num} x {i} = {num * i}")

# Main program
number = int(input("Enter a number: "))

# Function call
multiplication_table(number)
# Out:
# Enter a number: 9
#
# Multiplication Table of 9
#
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# **Create a simple data store using lists**

# %%
# Create an empty list
data_store = []

# Get the number of items to store
n = int(input("How many items do you want to store? "))

# Store items in the list
for i in range(n):
    item = input(f"Enter item {i + 1}: ")
    data_store.append(item)

# Display the stored items
print("\nStored Data:")
for item in data_store:
    print(item)
# Out:
# How many items do you want to store? 5
# Enter item 1: iqoo
# Enter item 2: realme
# Enter item 3: oneplus
# Enter item 4: smasung
# Enter item 5: iphone
#
# Stored Data:
# iqoo
# realme
# oneplus
# smasung
# iphone

# %% [markdown]
# **Add Student Names Into a Lists**

# %%
# Create an empty list
students = []

# Input the number of students
n = int(input("Enter the number of students: "))

# Add student names to the list
for i in range(n):
    name = input(f"Enter name of student {i + 1}: ")
    students.append(name)

# Display the student names
print("\nList of Student Names:")
for name in students:
    print(name)
# Out:
# Enter the number of students: 3
# Enter name of student 1: ARJUN
# Enter name of student 2: VIKRAM
# Enter name of student 3: ADITYA
#
# List of Student Names:
# ARJUN
# VIKRAM
# ADITYA

# %% [markdown]
# **Display all Student Names using a Loop**

# %%
# List of student names
students = ["ARJUN", "VIKRAM", "ADITYA"]

# Display all student names using a loop
print("Student Names:")

for student in students:
    print(student)
# Out:
# Student Names:
# ARJUN
# VIKRAM
# ADITYA

# %% [markdown]
# **Create a Function to Add Numbers**

# %%
# Function to add two numbers
def add_numbers(a, b):
    return a + b

# Input from the user
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

# Function call
result = add_numbers(num1, num2)

# Display the result
print("Sum =", result)
# Out:
# Enter first number: 18
# Enter second number: 29
# Sum = 47

# %% [markdown]
# **Create a Function to Display Student Details**

# %%
# Function to display student details
def display_student(name, age, course):
    print("\nStudent Details")
    print("Name   :", name)
    print("Age    :", age)
    print("Course :", course)

# Input from the user
name = input("Enter student name: ")
age = int(input("Enter student age: "))
course = input("Enter student course: ")

# Function call
display_student(name, age, course)
# Out:
# Enter student name: ARJUN
# Enter student age: 20
# Enter student course: BTECH
#
# Student Details
# Name   : ARJUN
# Age    : 20
# Course : BTECH
